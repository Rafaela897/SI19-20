# %%
import pandas as pd
import numpy as np

# %%
Absents = pd.read_csv("train_data.csv")

# %%
Absents
# Out:
#       ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0      1                  26                 7                3        1
# 1      2                   0                 7                3        1
# 2      3                  23                 7                4        1
# 3      4                   7                 7                5        1
# 4      5                  23                 7                5        1
# ..   ...                 ...               ...              ...      ...
# 495  496                  28                 9                3        1
# 496  497                  28                 9                3        1
# 497  498                  28                 9                3        1
# 498  499                  23                 9                3        1
# 499  500                  28                 9                5        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
Absents.drop(2)
# Out:
#       ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0      1                  26                 7                3        1
# 1      2                   0                 7                3        1
# 3      4                   7                 7                5        1
# 4      5                  23                 7                5        1
# 5      6                  23                 7                6        1
# ..   ...                 ...               ...              ...      ...
# 495  496                  28                 9                3        1
# 496  497                  28                 9                3        1
# 497  498                  28                 9                3        1
# 498  499                  23                 9                3        1
# 499  500                  28                 9                5        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %% [markdown]
# ## Removemos os outliers

# %%
x = Absents.quantile(0.75)
x['ID']

print([x for x in Absents])
# Out:
# ['ID', 'Reason for absence', 'Month of absence', 'Day of the week', 'Seasons', 'Transportation expense', 'Distance from Residence to Work', 'Service time', 'Age', 'Work load Average/day ', 'Hit target', 'Disciplinary failure', 'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index', 'Absent']

# %%
# Out:
#            ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    0.000000            0.928571          0.545455             0.25      0.0
# 1    0.002004            0.000000          0.545455             0.25      0.0
# 2    0.004008            0.821429          0.545455             0.50      0.0
# 3    0.006012            0.250000          0.545455             0.75      0.0
# 4    0.008016            0.821429          0.545455             0.75      0.0
# ..        ...                 ...               ...              ...      ...
# 495  0.991984            1.000000          0.727273             0.25      0.0
# 496  0.993988            1.000000          0.727273             0.25      0.0
# 497  0.995992            1.000000          0.727273             0.25      0.0
# 498  0.997996            0.821429          0.727273             0.25      0.0
# 499  1.000000            1.000000          0.727273             0.75      0.0
#
# ...

# %% [markdown]
# ## Normalizar os dados

# %%
abs = [x for x in Absents['Absent'] if x == 1]
workload = [x.replace(",","") for x in Absents['Work load Average/day ']]
Absents['Work load Average/day '] = workload
return Absents

Absents = normalize_dataset()

Absents
# Out:
#       ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0      1                  26                 7                3        1
# 1      2                   0                 7                3        1
# 2      3                  23                 7                4        1
# 3      4                   7                 7                5        1
# 4      5                  23                 7                5        1
# ..   ...                 ...               ...              ...      ...
# 495  496                  28                 9                3        1
# 496  497                  28                 9                3        1
# 497  498                  28                 9                3        1
# 498  499                  23                 9                3        1
# 499  500                  28                 9                5        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
from sklearn import preprocessing
x = Absents.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)

i = 0
for x in Absents:
    Absents[x] = df[i]
    i+=1
    
Absents
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.000004  0.000109  0.000029  0.000013  0.000004  0.001206  0.000150
# 1    0.000008  0.000000  0.000029  0.000013  0.000004  0.000493  0.000054
# 2    0.000013  0.000096  0.000029  0.000017  0.000004  0.000747  0.000213
# 3    0.000017  0.000029  0.000029  0.000021  0.000004  0.001165  0.000021
# 4    0.000021  0.000096  0.000029  0.000021  0.000004  0.001206  0.000150
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.001895  0.000107  0.000034  0.000011  0.000004  0.000940  0.000096
# 496  0.001899  0.000107  0.000034  0.000011  0.000004  0.000940  0.000096
# 497  0.001903  0.000107  0.000034  0.000011  0.000004  0.000451  0.000038
# 498  0.001906  0.000088  0.000034  0.000011  0.000004  0.000592  0.000046
# 499  0.001910  0.000107  0.000034  0.000019  0.000004  0.001112  0.000118
#
#            7         8         9   ...        11        12        13  \
# ...

# %% [markdown]
# ## Balancear o dataset

# %%
Max = dict()
for x in Absents:
    Max[x] = max(Absents[x])          
print(Max)

for i in Abesents:
    for x in Abesents[i]:
# Out:
#   File "<ipython-input-51-56fea2003f87>", line 8
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
